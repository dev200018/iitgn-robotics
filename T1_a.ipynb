# %%
# Name - Dev Patel
# Roll No - 18110113



import numpy as np

# Some constants
L1 = 0.25
L2 = 0.25
L3 = 0.25

A = np.array([0.45,0.075,0.1])
B = np.array([0.45,-0.075,0.1])
C = np.array([0.25,-0.075,0.1])
D = np.array([0.25,0.075,0.1])

#STANFORD
def inverse_kinematics_Stanford(O):

    r = (O[0]**2 + O[1]**2)**0.5
    s = O[2] - L1
    theta1 = np.arctan2(O[1],O[0]) 
    d3 = (r**2 + s**2  - L2**2)**0.5
    theta2 = -np.arctan2(-s,r) + np.arctan2(d3,L2)
    

    I = np.array([theta1,theta2,d3])
    return(I)
# Forward Kinematics 

def check_end_Effector_position_Stanford(I):
    T = np.eye(4)
    DH_parameters = np.array([[I[0],0,L1,1.57],[I[1],L2,0,1.57],[0,0,I[2],0]])
    for i in range(3):
        A = np.array([[np.cos(DH_parameters[i,0]), -np.sin(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), np.sin(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.cos(DH_parameters[i,0])],\
                [np.sin(DH_parameters[i,0]), np.cos(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), -np.cos(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.sin(DH_parameters[i,0])],\
                    [0,np.sin(DH_parameters[i,3]),np.cos(DH_parameters[i,3]),DH_parameters[i,2]],\
                        [0,0,0,1]])

        T = np.dot(T,A)
    return(print('x=',T[0,3],'y=',T[1,3],'z=',T[2,3]))

input = inverse_kinematics_Stanford(A)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))

input = inverse_kinematics_Stanford(B)
print(" For point B \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))

input = inverse_kinematics_Stanford(C)
print(" For point C \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))

input = inverse_kinematics_Stanford(D)
print(" For point D \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))
# Out:
#  For point A
#  Theta1 =  0.16514867741462683
#  Theta2 = 0.7056039475462993
#  Extension:  0.4100304866714181
#
# x= 0.45007323336988836 y= 0.07456008694833352 z= 0.10000040653978098
# None
#  For point B
#  Theta1 =  -0.16514867741462683
#  Theta2 = 0.7056039475462993
#  Extension:  0.4100304866714181
#
# x= 0.44992660030611065 y= -0.07543988533099963 z= 0.10000040653978098
# None
#  For point C
#  Theta1 =  -0.2914567944778671
#  Theta2 = 0.06926713645627891
#  Extension:  0.16770509831248426
#
# x= 0.24992729833017968 y= -0.07524232609171155 z= 0.10000020695452305
# None
#  For point D
#  Theta1 =  0.2914567944778671
#  Theta2 = 0.06926713645627891
#  Extension:  0.16770509831248426
#
# x= 0.25007269461971604 y= 0.07475767179325717 z= 0.10000020695452305
# None

# %%
# SCARA manipulator
d1 = 0.25
# Some constants
L1 = 0.25
L2 = 0.25
L3 = 0.25
def inverse_kinematics_SCARA(O):

    c2 = (O[0]**2 + O[1]**2 - L1**2 - L2**2)/(2*L1*L2)
    theta2 = np.arctan2(-(1-c2**2)**0.5,c2)
    theta1 = np.arctan2(O[1],O[0]) - np.arctan2(L2*np.sin(theta2),L1 + L2*np.cos(theta2))

    d3 = d1 - O[2] 

    I = np.array([theta1,theta2,d3])
    return(I)

# gets the value of end effector position for the given joint variables
def check_end_Effector_position_SCARA(I):
    T = np.eye(4)
    DH_parameters = np.array([[0,0,d1,0],[I[0],L1,0,0],[I[1],L1,0,3.14],[0,0,I[2],0]])
    for i in range(4):
        A = np.array([[np.cos(DH_parameters[i,0]), -np.sin(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), np.sin(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.cos(DH_parameters[i,0])],\
                [np.sin(DH_parameters[i,0]), np.cos(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), -np.cos(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.sin(DH_parameters[i,0])],\
                    [0,np.sin(DH_parameters[i,3]),np.cos(DH_parameters[i,3]),DH_parameters[i,2]],\
                        [0,0,0,1]])

        T = np.dot(T,A)
    return(print('x=',T[0,3],'y=',T[1,3],'z=',T[2,3]))

input = inverse_kinematics_SCARA(A)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))

input = inverse_kinematics_SCARA(B)
print(" For point B \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))

input = inverse_kinematics_SCARA(C)
print(" For point C \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))

input = inverse_kinematics_SCARA(D)
print(" For point D \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))
# Out:
#  For point A
#  Theta1 =  0.5867999318113676
#  Theta2 = -0.8433025087934816
#  Extension:  0.15
#
# x= 0.44993939180542125 y= 0.07476891804207433 z= 0.10000019024086909
# None
#  For point B
#  Theta1 =  0.256502576982114
#  Theta2 = -0.8433025087934816
#  Extension:  0.15
#
# x= 0.4498677224241793 y= -0.07519893432952574 z= 0.10000019024086909
# None
#  For point C
#  Theta1 =  0.7301274759840087
#  Theta2 = -2.0431685409237517
#  Extension:  0.15
#
# x= 0.24976899414633208 y= -0.07506089761982242 z= 0.10000019024086909
# None
#  For point D
#  Theta1 =  1.313041064939743
#  Theta2 = -2.0431685409237517
#  Extension:  0.15
#
# x= 0.24984066352757403 y= 0.07482199968234945 z= 0.10000019024086909
# None

# %%
# PUMA

def inverse_kinematics_PUMA(O):

    r = (O[0]**2 + O[1]**2)**0.5
    s = O[2] - L1
    theta1 = np.arctan2(O[1],O[0])
    d = (r**2 + s**2 - L2**2 - L3**2)/(2*L2*L3)
    theta3 = np.arctan2(((1-d**2)**0.5),d)
    theta2 = np.arctan2(s,r) - np.arctan2(L3*np.sin(theta3),L2 + L3*np.cos(theta3))

    I = np.array([theta1,theta2,theta3])
    return(I)

# gets the value of end effector position for the given joint variables
def check_end_Effector_position_PUMA(I):
    T = np.eye(4)
    DH_parameters = np.array([[I[0],0,L1,1.57],[I[1],L2,0,0],[I[2],L3,0,0]])
    for i in range(3):
        A = np.array([[np.cos(DH_parameters[i,0]), -np.sin(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), np.sin(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.cos(DH_parameters[i,0])],\
                [np.sin(DH_parameters[i,0]), np.cos(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), -np.cos(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.sin(DH_parameters[i,0])],\
                    [0,np.sin(DH_parameters[i,3]),np.cos(DH_parameters[i,3]),DH_parameters[i,2]],\
                        [0,0,0,1]])

        T = np.dot(T,A)
    return(print('x=',T[0,3],'y=',T[1,3],'z=',T[2,3]))

input = inverse_kinematics_PUMA(A)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))

input = inverse_kinematics_PUMA(B)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))

input = inverse_kinematics_PUMA(C)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))

input = inverse_kinematics_PUMA(D)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))
# Out:
#  For point A
#  Theta1 =  0.16514867741462683
#  Theta2 = -0.5997787728460517
#  Theta3  0.5642311597275824
#
# x= 0.45001963729572125 y= 0.0748821762256721 z= 0.10000004756022482
# None
#  For point A
#  Theta1 =  -0.16514867741462683
#  Theta2 = -0.5997787728460517
#  Theta3  0.5642311597275824
#
# x= 0.44998036270427866 y= -0.07511782377432785 z= 0.10000004756022482
# None
#  For point A
#  Theta1 =  -0.2914567944778671
#  Theta2 = -1.4462986282824137
#  Theta3  1.8493860291865472
#
# x= 0.24996567658051766 y= -0.07511441139827463 z= 0.10000004756022485
# None
#  For point A
#  Theta1 =  0.2914567944778671
#  Theta2 = -1.4462986282824137
#  Theta3  1.8493860291865472
#
# x= 0.2500343234194824 y= 0.07488558860172541 z= 0.10000004756022485
# None
