# %%
# Name - Dev Patel
# Roll No - 18110113



import numpy as np

links = 3
# Some constants
L1 = 0.25
L2 = 0.25
L3 = 0.25

A = np.array([0.4,0.06,0.15])
B = np.array([0.4,0.01,0.15])
C = np.array([0.35,0.01,0.15])
D = np.array([0.35,0.06,0.15])

#STANFORD
def inverse_kinematics_Stanford(O):

    r = (O[0]**2 + O[1]**2)**0.5
    s = O[2] - L1
    theta1 = np.arctan2(O[1],O[0]) 
    d3 = (r**2 + s**2  - L2**2)**0.5
    theta2 = -np.arctan2(-s,r) + np.arctan2(d3,L2)
    

    I = np.array([theta1,theta2,d3])
    return(I)
# Forward Kinematics 

def check_end_Effector_position_Stanford(I):
    T = np.eye(4)
    DH_parameters = np.array([[I[0],0,L1,1.57],[I[1],L2,0,1.57],[0,0,I[2],0]])
    for i in range(3):
        A = np.array([[np.cos(DH_parameters[i,0]), -np.sin(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), np.sin(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.cos(DH_parameters[i,0])],\
                [np.sin(DH_parameters[i,0]), np.cos(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), -np.cos(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.sin(DH_parameters[i,0])],\
                    [0,np.sin(DH_parameters[i,3]),np.cos(DH_parameters[i,3]),DH_parameters[i,2]],\
                        [0,0,0,1]])

        T = np.dot(T,A)
    return(print('x=',T[0,3],'y=',T[1,3],'z=',T[2,3]))

input = inverse_kinematics_Stanford(A)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))

input = inverse_kinematics_Stanford(B)
print(" For point B \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))

input = inverse_kinematics_Stanford(C)
print(" For point C \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))

input = inverse_kinematics_Stanford(D)
print(" For point D \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_Stanford(input))
# Out:
#  For point A
#  Theta1 =  0.14888994760949723
#  Theta2 = 0.6848974539848873
#  Extension:  0.3333166662499792
#
# x= 0.400051120461726 y= 0.05965874623500634 z= 0.15000032492560395
# None
#  For point B
#  Theta1 =  0.02499479361892016
#  Theta2 = 0.6746665973469224
#  Extension:  0.32802438933713457
#
# x= 0.40000845357028425 y= 0.009659257734600014 z= 0.15000032093888327
# None
#  For point C
#  Theta1 =  0.028563657838759998
#  Theta2 = 0.5358795888054534
#  Extension:  0.2647640458974745
#
# x= 0.350008252946327 y= 0.009709646034433451 z= 0.1500002717836392
# None
#  For point D
#  Theta1 =  0.16977827396833844
#  Theta2 = 0.5517246893880178
#  Extension:  0.2712931993250107
#
# x= 0.3500499131878331 y= 0.05970857289264833 z= 0.1500002769988146
# None

# %%
# SCARA manipulator
d1 = 0.25
# Some constants
L1 = 0.25
L2 = 0.25
L3 = 0.25
def inverse_kinematics_SCARA(O):

    c2 = (O[0]**2 + O[1]**2 - L1**2 - L2**2)/(2*L1*L2)
    theta2 = np.arctan2(-(1-c2**2)**0.5,c2)
    theta1 = np.arctan2(O[1],O[0]) - np.arctan2(L2*np.sin(theta2),L1 + L2*np.cos(theta2))

    d3 = d1 - O[2] 

    I = np.array([theta1,theta2,d3])
    return(I)

# gets the value of end effector position for the given joint variables
def check_end_Effector_position_SCARA(I):
    T = np.eye(4)
    DH_parameters = np.array([[0,0,d1,0],[I[0],L1,0,0],[I[1],L1,0,3.14],[0,0,I[2],0]])
    for i in range(4):
        A = np.array([[np.cos(DH_parameters[i,0]), -np.sin(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), np.sin(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.cos(DH_parameters[i,0])],\
                [np.sin(DH_parameters[i,0]), np.cos(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), -np.cos(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.sin(DH_parameters[i,0])],\
                    [0,np.sin(DH_parameters[i,3]),np.cos(DH_parameters[i,3]),DH_parameters[i,2]],\
                        [0,0,0,1]])

        T = np.dot(T,A)
    return(print('x=',T[0,3],'y=',T[1,3],'z=',T[2,3]))

input = inverse_kinematics_SCARA(A)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))

input = inverse_kinematics_SCARA(B)
print(" For point B \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))

input = inverse_kinematics_SCARA(C)
print(" For point C \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))

input = inverse_kinematics_SCARA(D)
print(" For point D \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Extension: ", input[2], "\n")
Check = print(check_end_Effector_position_SCARA(input))
# Out:
#  For point A
#  Theta1 =  0.7773225547941871
#  Theta2 = -1.2568652143693797
#  Extension:  0.1
#
# x= 0.3999265192199601 y= 0.05985869887442536 z= 0.15000012682724606
# None
#  For point B
#  Theta1 =  0.6680791850484008
#  Theta2 = -1.2861687828589612
#  Extension:  0.1
#
# x= 0.3999077090656939 y= 0.009870200860677613 z= 0.15000012682724606
# None
#  For point C
#  Theta1 =  0.8235624111580746
#  Theta2 = -1.5899975066386292
#  Extension:  0.1
#
# x= 0.3498895381267802 y= 0.009885267233587281 z= 0.15000012682724606
# None
#  For point D
#  Theta1 =  0.9507763805744743
#  Theta2 = -1.5619962132122718
#  Extension:  0.1
#
# x= 0.3499086029260525 y= 0.05986956991145529 z= 0.15000012682724606
# None

# %%
# PUMA

def inverse_kinematics_PUMA(O):

    r = (O[0]**2 + O[1]**2)**0.5
    s = O[2] - L1
    theta1 = np.arctan2(O[1],O[0])
    d = (r**2 + s**2 - L2**2 - L3**2)/(2*L2*L3)
    theta3 = np.arctan2(((1-d**2)**0.5),d)
    theta2 = np.arctan2(s,r) - np.arctan2(L3*np.sin(theta3),L2 + L3*np.cos(theta3))

    I = np.array([theta1,theta2,theta3])
    return(I)

# gets the value of end effector position for the given joint variables
def check_end_Effector_position_PUMA(I):
    T = np.eye(4)
    DH_parameters = np.array([[I[0],0,L1,1.57],[I[1],L2,0,0],[I[2],L3,0,0]])
    for i in range(3):
        A = np.array([[np.cos(DH_parameters[i,0]), -np.sin(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), np.sin(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.cos(DH_parameters[i,0])],\
                [np.sin(DH_parameters[i,0]), np.cos(DH_parameters[i,0])*np.cos(DH_parameters[i,3]), -np.cos(DH_parameters[i,0])*np.sin(DH_parameters[i,3]),DH_parameters[i,1]*np.sin(DH_parameters[i,0])],\
                    [0,np.sin(DH_parameters[i,3]),np.cos(DH_parameters[i,3]),DH_parameters[i,2]],\
                        [0,0,0,1]])

        T = np.dot(T,A)
    return(print('x=',T[0,3],'y=',T[1,3],'z=',T[2,3]))

input = inverse_kinematics_PUMA(A)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))

input = inverse_kinematics_PUMA(B)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))

input = inverse_kinematics_PUMA(C)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))

input = inverse_kinematics_PUMA(D)
print(" For point A \n Theta1 = ", input[0], "\n Theta2 =", input[1],"\n Theta3 ", input[2], "\n")
Check = print(check_end_Effector_position_PUMA(input))
# Out:
#  For point A
#  Theta1 =  0.14888994760949723
#  Theta2 = -0.8281075469386558
#  Theta3  1.1714675685800386
#
# x= 0.4000118127464951 y= 0.05992124835669958 z= 0.15000003170681653
# None
#  For point A
#  Theta1 =  0.02499479361892016
#  Theta2 = -0.8457405660216906
#  Theta3  1.201670798415782
#
# x= 0.4000019901949382 y= 0.009920392202477517 z= 0.15000003170681658
# None
#  For point A
#  Theta1 =  0.028563657838759998
#  Theta2 = -1.033171307471505
#  Theta3  1.5099588050590336
#
# x= 0.3500022742910807 y= 0.009920399812171375 z= 0.1500000317068165
# None
#  For point A
#  Theta1 =  0.16977827396833844
#  Theta2 = -1.01543725985284
#  Theta3  1.4818792062087518
#
# x= 0.35001345503991205 y= 0.059921512267179906 z= 0.15000003170681647
# None
