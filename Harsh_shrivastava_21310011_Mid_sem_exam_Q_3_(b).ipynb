# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("Gait_DATA.xlsx")

# %%
df.head()
# Out:
#       X (cm)     Y (cm)
# 0  46.108625  12.809129
# 1  45.628312  12.786217
# 2  45.105438  12.732817
# 3  44.568188  12.646511
# 4  44.005938  12.526861

# %%
plt.figure(figsize=(15,10))
plt.plot(df['X (cm)'],df['Y (cm)'])
plt.title('Ankle coordinates plot')
plt.xlabel('X-Ankle coordinate(cm)')
plt.ylabel('Y-Ankle coordinate(cm)')
plt.show()
